# %%
# %ls
# Out:
#  驱动器 F 中的卷没有标签。
#  卷的序列号是 407C-D6A6
#
#  F:\repository\shujuren_Python\5data_analysis\notebook 的目录
#
# 2018/01/17 周三  16:07    <DIR>          .
# 2018/01/17 周三  16:07    <DIR>          ..
# 2018/01/17 周三  16:07    <DIR>          .ipynb_checkpoints
# 2018/01/17 周三  16:07                72 1.analysis_data.ipynb
#                1 个文件             72 字节
#                3 个目录 212,887,232,512 可用字节

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
plt.plot(np.random.randn(100))

# %%
plt.plot([3, -5, 7, 2])

# %%
x = [0.8, 1.2, 2.1, 2.8]
y = [2, -5, 3.2, 5]
plt.plot(x,y)

# %%
list(zip(x,y))
# Out:
# [(0.8, 2), (1.2, -5), (2.1, 3.2), (2.8, 5)]

# %%
points = list(zip(x,y))

# %%
points
# Out:
# [(0.8, 2), (1.2, -5), (2.1, 3.2), (2.8, 5)]

# %%
X,Y = zip(*points)

# %%
X
# Out:
# (0.8, 1.2, 2.1, 2.8)

# %%
Y
# Out:
# (2, -5, 3.2, 5)

# %% [markdown]
# ## 品牌的文本介绍数据挖掘

# %% [markdown]
# ### 需要使用的套件
#
# * numpy
# * matplotlib
# * scikit-learn

# %% [markdown]
# 函数$f(x)=x^2$，计算积分
#
# $$\int_a^b f(x) \, dx$$

# %%
from ipywidgets import interact

# %%
def f(x):
    print(x)

# %%
interact(f, x=3)
# Out:
# 3
# <function __main__.f>
